# %% [markdown]
# <a href="https://colab.research.google.com/github/ram-shankar58/SEDS-Project-practice/blob/main/graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
 #Matplotlib 

#Defining the figure plotting
plt.figure(figsize=(10,8), facecolor="blue")
plt.plot([1.0,5.0],[1,5])
plt.xlabel("X axis")
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')
